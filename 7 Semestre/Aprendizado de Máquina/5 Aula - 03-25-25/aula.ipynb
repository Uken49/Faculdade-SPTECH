# %%
# importar as bibliotecas necessárias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# carregar o conjunto de dados
dataset = pd.read_csv('/content/50_Startups.csv')

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Identificar a coluna categórica ("State")
column_transformer = ColumnTransformer(
    transformers=[("encoder", OneHotEncoder(), [3])], remainder="passthrough"
)

# separar as variáveis dependentes e independentes
X = column_transformer.fit_transform(dataset.iloc[:, :-1].values)
y = dataset.iloc[:, -1].values

#Dividir o dataset em Treinamento e Teste
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

#Regressão Polinomial
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X_train)
regressor = LinearRegression()
regressor.fit(X_poly, y_train)
y_pred = regressor.predict(poly_reg.transform(X_test))

# calcular a métrica de erro
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("coeficiente angular (declividade da linha): ", regressor.coef_)
print("ponto onde y é interceptado: ", regressor.intercept_)
print("R2 Score: ", r2)
# Out:
# coeficiente angular (declividade da linha):  [-2.97338027e-16  2.25592141e-17  2.67041659e-17 -1.47358941e-17
#   1.16634212e-17  7.06468213e-18 -1.60717108e-19  3.05928749e-18
#  -9.79916686e-18 -1.07711494e-18  5.07441610e-18  9.78338640e-18
#   1.76836303e-17  2.49243236e-19  1.10624807e-19  3.31335721e-19
#   1.46478709e-19 -5.96614084e-19  7.95837576e-21 -4.18512320e-18
#  -8.18210639e-18 -1.17522024e-17  9.48014545e-15  1.37497499e-14
#   8.07526127e-14  1.97536686e-14  1.71546615e-13  4.86425329e-13
#   1.10467386e-22 -5.06131137e-23  8.95423013e-23  4.53754257e-18
#   8.25626122e-18  1.78889913e-17  3.37980828e-23 -9.20238431e-24
#   5.68686671e-24 -3.82571033e-24 -1.24077092e-24  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  1.81803555e-13
#   2.35398193e-13  6.06269365e-13  4.25712415e-13  8.77289755e-13
#   2.19588189e-12 -2.76390285e-25  0.00000000e+00  3.23583347e-19
#   2.09509883e-19 -5.85959131e-19  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  3.27168141e-14  2.82768984e-14
#   2.63399278e-14  2.71859254e-14 -9.99883115e-15 -6.86989895e-14
#  -1.26193990e-22 -4.19816489e-18 -8.17693677e-18 -1.17518161e-17
#  -2.05040223e-13 -2.49925341e-13 -5.51856679e-13 -4.33144673e-13
#  -6.95744309e-13 -1.64075757e-12  1.22321621e-11  2.44688240e-10
#   4.03223824e-10 -2.63811968e-10  2.63950010e-10 -4.06367412e-10
#   1.06370618e-10  2.69498173e-11 -9.66686219e-11  9.31251338e-11
#   1.26470380e-22  0.00000000e+00  0.00000000e+00  4.53761099e-18
#   8.25619250e-18  1.78889252e-17  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  1.81803555e-13
#   2.35398193e-13  6.06269365e-13  4.25712415e-13  8.77289755e-13
#   2.19588189e-12  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.94073812e-10 -4.49961896e-10
#  -1.66321059e-10 -8.57886205e-12  2.86362656e-10 -8.26691192e-11
#   6.10469895e-11 -3.77310974e-11 -3.34600339e-11  2.41760188e-11
#  -2.76390285e-25  0.00000000e+00  3.23583347e-19  2.09509883e-19
#  -5.85959131e-19  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  3.27168141e-14  2.82768984e-14  2.63399278e-14
#   2.71859254e-14 -9.99883115e-15 -6.86989895e-14  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -3.56462957e-10  4.74527582e-10  2.45407566e-10
#  -1.68817094e-10 -4.00365417e-11 -1.32125509e-10 -1.61948747e-11
#   1.07349747e-10 -6.01389574e-11  3.36561150e-11 -1.26193990e-22
#  -4.19816489e-18 -8.17693677e-18 -1.17518161e-17 -2.05040223e-13
#  -2.49925341e-13 -5.51856679e-13 -4.33144673e-13 -6.95744309e-13
#  -1.64075757e-12 -2.25378693e-10  2.20122554e-10  3.24137317e-10
#  -8.64160118e-11  1.76238952e-11 -1.91572784e-10  6.15185036e-11
#  -4.26688322e-11 -3.06963059e-12  3.52929999e-11 -1.40280704e-14
#   2.24866655e-14  5.40583582e-15 -1.31694770e-14 -1.29060479e-14
#  -1.20253355e-16  4.27202959e-15  3.09884033e-15  2.57525918e-15
#   4.65357611e-16 -1.17214936e-15 -3.17457616e-16 -9.99703424e-17
#  -1.24591693e-16 -1.96293017e-16]
# ponto onde y é interceptado:  21007.785261146288
# R2 Score:  -8.402979412783399

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_poly, y_train)

#Regressão Linear Múltipla
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# calcular a métrica de erro
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("coeficiente angular (declividade da linha): ", regressor.coef_)
print("ponto onde y é interceptado: ", regressor.intercept_)
print("R2 Score: ", r2)
# Out:
# coeficiente angular (declividade da linha):  [ 8.66383692e+01 -8.72645791e+02  7.86007422e+02  7.73467193e-01
#   3.28845975e-02  3.66100259e-02]
# ponto onde y é interceptado:  42467.52924853278
# R2 Score:  0.9347068473282546
